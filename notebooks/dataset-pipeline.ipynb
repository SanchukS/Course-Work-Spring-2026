# %% [markdown]
# ### Импорты

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

root_path = Path.cwd().parent
if str(root_path) not in sys.path:
    sys.path.append(str(root_path))

# %%
import numpy as np
import pandas as pd

from pathlib import Path
from src.multiple_datasets_constructor import build_multiple_datasets

# %% [markdown]
# ### Глобальные константы

# %%
dataset_folder_path = Path("./data/Dunnhumby")
dataset_path = dataset_folder_path / "outflow_data.csv"

files_folder_path = Path("./data/files")

# %%
WINDOW_SIZE = 5

# %% [markdown]
# ### Построение датасета

# %%
outflow_data = pd.read_csv(dataset_path)

# %%
outflow_data
# Out:
#         DAY  household_key TOTAL CATEGORY  WEIGHT_GR  VOLUME_ML  COUNT  \
# 0       221            766        ALMONDS     453.59        0.0    0.0
# 1       263            766        ALMONDS     453.59        0.0    0.0
# 2       281            766        ALMONDS     453.59        0.0    0.0
# 3       295            766        ALMONDS     453.59        0.0    0.0
# 4       306            766        ALMONDS     453.59        0.0    0.0
# ...     ...            ...            ...        ...        ...    ...
# 412101  318           2322       ZUCCHINI    8164.62        0.0    0.0
# 412102  347           2322       ZUCCHINI    8164.62        0.0    0.0
# 412103  362           2322       ZUCCHINI    8164.62        0.0    0.0
# 412104  380           2322       ZUCCHINI    8164.62        0.0    0.0
# 412105  402           2322       ZUCCHINI    8164.62        0.0    0.0
#
#         SESSION_ID
# 0                2
# 1                2
# 2                2
# 3                2
# 4                2
# ...            ...
# 412101           1
# 412102           1
# 412103           1
# 412104           1
# 412105           1
#
# [412106 rows x 7 columns]

# %%
datasets = build_multiple_datasets(outflow_data, window_size=WINDOW_SIZE, datasets_proportions=[0.7, 0.15, 0.15], random_state=42)
# Out:
# Building dataset: 1
# Building dataset: 100%|██████████████████████████████████| 15290/15290 [02:54<00:00, 87.66session/s]
# Building dataset: 2
# Building dataset: 100%|████████████████████████████████████| 3276/3276 [00:33<00:00, 98.06session/s]
# Building dataset: 3
# Building dataset: 100%|████████████████████████████████████| 3277/3277 [00:38<00:00, 84.78session/s]

# %%
X_train, y_train = datasets[0]
X_val, y_val = datasets[1]
X_test, y_test = datasets[2]

# %%
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((258135, 31), (55807, 31), (54478, 31))

# %%
X_train["target"] = y_train
X_val["target"] = y_val
X_test["target"] = y_test

# %%
X_train.to_csv(dataset_folder_path / "dataset_train.csv", index=False)
X_val.to_csv(dataset_folder_path / "dataset_val.csv", index=False)
X_test.to_csv(dataset_folder_path / "dataset_test.csv", index=False)

# %%
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((258135, 32), (55807, 32), (54478, 32))
